# %%
# Importing Dependencies
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Reading in CSV file
df = pd.read_csv('crypto_data.csv')
df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
# Checking no. of values of coins traded vs not 
df['IsTrading'].value_counts()
# Out:
# True     1144
# False     108
# Name: IsTrading, dtype: int64

# %%
# Filtering out coins not being traded
df = df[df['IsTrading'] == True]
df
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
# Deleting 'IsTrading' column
df = df.drop('IsTrading', axis = 1)
df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
# Removing all rows that have at least one null value
df = df.dropna(axis=0, how="any")
df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 4        808        808   SHA-256   PoW/PoS     0.000000e+00               0
# 5       1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC    Bitcoin   SHA-256       PoW     1.792718e+07        21000000

# %%
# Sort Values to ID negative and values less than 0
df['TotalCoinsMined'].sort_values()
# Out:
# 1200   -5.917978e+09
# 784     0.000000e+00
# 156     0.000000e+00
# 544     0.000000e+00
# 533     0.000000e+00
#             ...
# 1052    9.955311e+10
# 783     1.430067e+11
# 769     1.630551e+11
# 210     1.840668e+11
# 1234    9.899887e+11
# Name: TotalCoinsMined, Length: 685, dtype: float64

# %%
# Deleting negative values and values with less than 0
df = df.loc[df['TotalCoinsMined'] > 0 ]
df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC    Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# 8        ETH   Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Renaming 'Unamed:0' column to Ticker
df.rename(columns={'Unnamed: 0':'Ticker'}, inplace=True)
df
# Out:
#      Ticker     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0        42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2       404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5      1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7       BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8       ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...     ...          ...          ...       ...              ...
# 1238   ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242    GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245    BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246    ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247    XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# 1238      2000000000
# ...

# %%
# Deleting 'Ticker' column
df = df.drop(['Ticker'], axis=1)
df.head()
# Out:
#     CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7    Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# 8   Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Deleting 'CoinName' column
df = df.drop(['CoinName'], axis=1)
df.head()
# Out:
#   Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    Scrypt   PoW/PoS     4.199995e+01              42
# 2    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       X13   PoW/PoS     2.927942e+10    314159265359
# 7   SHA-256       PoW     1.792718e+07        21000000
# 8    Ethash       PoW     1.076842e+08               0

# %%
# Convert the remaining features with text values, Algorithm and ProofType, into numerical data with get_dummies()
dumDF = pd.get_dummies(df, columns=['Algorithm', 'ProofType'])
dumDF.head()
# Out:
#    TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0     4.199995e+01              42                                 0
# 2     1.055185e+09       532000000                                 0
# 5     2.927942e+10    314159265359                                 0
# 7     1.792718e+07        21000000                                 0
# 8     1.076842e+08               0                                 0
#
#    Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0              0                  0                   0                0
# 2              0                  0                   0                0
# 5              0                  0                   0                0
# 7              0                  0                   0                0
# 8              0                  0                   0                0
#
#    Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# ...

# %%
print(dumDF.shape)
# Out:
# (532, 98)

# %%
# Standardize dataset so that columns that contain larger values do not unduly influence the outcome.
scaledDF = MinMaxScaler().fit_transform(dumDF)
print(scaledDF)
# Out:
# [[0.00000000e+00 4.20000000e-11 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.06585544e-03 5.32000000e-04 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.95755135e-02 3.14159265e-01 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [9.90135079e-04 1.40022261e-03 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [7.37028150e-06 2.10000000e-05 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.29582282e-07 1.00000000e-06 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
# Data Dimensionality Reduction with PCA
pca = PCA(n_components = .90)
principalComponents = pca.fit_transform(scaledDF)
principalComponents.shape
# Out:
# (532, 28)

# %%
# Comparison between change of Features
print(f'Scaled Dataframe Shape: {scaledDF.shape}')
print(f'PCA Shape: {principalComponents.shape}')
# Out:
# Scaled Dataframe Shape: (532, 98)
# PCA Shape: (532, 28)

# %%
# Further reduce the dataset dimensions with t-SNE 
tsne = TSNE()
tsneFeatures = tsne.fit_transform(principalComponents)
tsneFeatures.shape
# Out:
# (532, 2)

# %%
print(f'Scaled Dataframe Shape: {scaledDF.shape}')
print(f't-SNE Shape: {tsneFeatures.shape}')
# Out:
# Scaled Dataframe Shape: (532, 98)
# t-SNE Shape: (532, 2)

# %%
# Plot t-SNE features
X = tsneFeatures[:,0]
y = tsneFeatures[:,1]

# %%
# Display scatter plot
plt.scatter(X,y)
plt.title("t-SNE Feature Clusters")
plt.show()

# %%
# Identify cluster with k-means
inertia = []
k = list(range(1,10))

for i in k:
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(principalComponents)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\jssrm\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# Display Elbow plot
elbow_df = pd.DataFrame({"k": k, "inertia": inertia})
elbow_df.plot.line(x="k", y="inertia")
plt.xlabel("K Means")
plt.ylabel("Inertia")
plt.title("Elbow Plot")
plt.plot(k , inertia, marker = 'x')

plt.show()

# %% [markdown]
# It is difficult to navigate through the vast world of Cryptocurrencies. So many factors need to be accounted for to be able to make a sound decision as to whether a coin is worth investing in for it to moon.
#
# To help make sense of it all we deployed Unsupervised ML strategies to identify and narrow down how we can classify our crypto currency model/portfolios.
#
# The Elbow plot exhibits a bend around when K Means = 4, suggesting 4 possible classifications available within the crypto world.
#
# Next time we hold a meeting I hope it will be about which color lambo were purchasing because I'm ready to go to the moon. Diamond Hand Lifer.
